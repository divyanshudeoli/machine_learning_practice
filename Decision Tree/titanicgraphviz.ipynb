# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz?

# %%
df=pd.read_csv('discrete_processed.csv')

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
dtc=DecisionTreeClassifier(max_depth=3)

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
f1_score(dtc.predict(xtest),ytest)
# Out:
# 0.7005649717514125

# %%
dot_data=export_graphviz(dtc,feature_names=xtrain.columns)

# %%
import graphviz

# %%
graphviz.Source(dot_data)

# %%
len(xtrain[xtrain['Pclass']==2])
# Out:
# 129

# %%
len(xtrain)
# Out:
# 668

# %%
xtrain[xtrain['Sex']==1]
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Q  S  Farem
# 750       2    1  0.0      1      1  0  1    2.0
# 448       3    1  0.0      2      1  0  0    2.0
# 610       3    1  3.0      1      5  0  1    3.0
# 216       3    1  2.0      0      0  0  1    1.0
# 669       1    1  3.0      1      0  0  1    3.0
# ..      ...  ...  ...    ...    ... .. ..    ...
# 251       3    1  2.0      1      1  0  1    1.0
# 111       3    1  0.0      1      0  0  0    2.0
# 856       1    1  4.0      1      1  0  1    3.0
# 469       3    1  0.0      2      1  0  0    2.0
# 431       3    1  1.0      1      0  0  1    2.0
#
# [231 rows x 8 columns]

# %%
xtrain[xtrain['Sex']==0]
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Q  S  Farem
# 131       3    0  1.0      0      0  0  1    0.0
# 621       1    0  4.0      1      0  0  1    3.0
# 545       1    0  4.0      0      0  0  1    2.0
# 805       3    0  3.0      0      0  0  1    0.0
# 682       3    0  1.0      0      0  0  1    1.0
# ..      ...  ...  ...    ...    ... .. ..    ...
# 552       3    0  2.0      0      0  1  0    0.0
# 768       3    0  1.0      1      0  1  0    2.0
# 104       3    0  3.0      2      0  0  1    1.0
# 495       3    0  2.0      0      0  0  0    2.0
# 21        2    0  3.0      0      0  0  1    1.0
#
# [437 rows x 8 columns]

# %%
p=dtc.predict(xtrain)
p(p)==1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-8ad5f1232d11> in <module>
#       1 p=dtc.predict(xtrain)
# ----> 2 p9p==1
#
# NameError: name 'p9p' is not defined
