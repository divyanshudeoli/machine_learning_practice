# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
train=pd.read_csv("train.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Q                0
# S                0
# dtype: int64

# %%
train['Sex'].replace(to_replace=['male','female'],value=[0,1],inplace=True)

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
train[['Q','S']]=pd.get_dummies(train['Embarked'],drop_first=True)

# %%
#train.drop(columns="Embarked",inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
#modified age
plt.hist(train['Age'],bins=30)
# Out:
# (array([ 30.,  14.,  10.,  14.,   6.,  30.,  40.,  77.,  79.,  71., 149.,
#          64.,  39.,  57.,  40.,  42.,  28.,  21.,  16.,  14.,  15.,   7.,
#           9.,   8.,   4.,   0.,   5.,   1.,   0.,   1.]),
#  array([ 0.42      ,  3.07266667,  5.72533333,  8.378     , 11.03066667,
#         13.68333333, 16.336     , 18.98866667, 21.64133333, 24.294     ,
#         26.94666667, 29.59933333, 32.252     , 34.90466667, 37.55733333,
#         40.21      , 42.86266667, 45.51533333, 48.168     , 50.82066667,
#         53.47333333, 56.126     , 58.77866667, 61.43133333, 64.084     ,
#         66.73666667, 69.38933333, 72.042     , 74.69466667, 77.34733333,
#         80.        ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(train['Age'],bins=30)
# Out:
# (array([30., 14., 10., 14.,  3., 29., 39., 65., 73., 42., 65., 62., 33.,
#         47., 38., 21., 28., 21., 16., 14., 15.,  7.,  9.,  8.,  4.,  0.,
#          5.,  1.,  0.,  1.]),
#  array([ 0.42      ,  3.07266667,  5.72533333,  8.378     , 11.03066667,
#         13.68333333, 16.336     , 18.98866667, 21.64133333, 24.294     ,
#         26.94666667, 29.59933333, 32.252     , 34.90466667, 37.55733333,
#         40.21      , 42.86266667, 45.51533333, 48.168     , 50.82066667,
#         53.47333333, 56.126     , 58.77866667, 61.43133333, 64.084     ,
#         66.73666667, 69.38933333, 72.042     , 74.69466667, 77.34733333,
#         80.        ]),
#  <BarContainer object of 30 artists>)

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.369226  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.093254  0.114631
# Age             0.036847 -0.077221 -0.369226 -0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.096067  0.159651
# Q              -0.033606  0.003650  0.221009  0.074115 -0.022405 -0.026354
# S               0.022204 -0.149683  0.074053 -0.119224 -0.023233  0.068734
#
#                 Parch      Fare         Q         S
# PassengerId -0.001652  0.012658 -0.033606  0.022204
# ...

# %%
lin=LinearRegression(fit_intercept=True)

# %%
a=train['Age'].isnull()

# %%
ytes=train[a]['Age']

# %%
ind=ytes.index

# %%
xtes=train[a][['Pclass','SibSp','Parch','Sex']]

# %%
ytr=train[a==False]['Age']

# %%
xtr=train[a==False][['Pclass','SibSp','Parch','Sex']]

# %%
len(xtr)+len(xtes)
# Out:
# 891

# %%
lin.fit(xtr,ytr)
# Out:
# LinearRegression()

# %%
fill=np.rint(lin.predict(xtes))

# %%
fill[fill<0]=29

# %%
train.loc[ind,'Age']=fill

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Q                0
# S                0
# dtype: int64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
from sklearn.preprocessing import KBinsDiscretizer

# %%
bin=KBinsDiscretizer(n_bins=4,encode='ordinal')

# %%
fare=bin.fit_transform(train['Fare'].values.reshape(-1,1))

# %%
train['Farem']=fare.reshape(-1)

# %%
sns.countplot(fare.reshape(-1),hue=train['Survived'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
agebin=KBinsDiscretizer(n_bins=5,encode='ordinal')

# %%
agemod=agebin.fit_transform(train['Age'].values.reshape(-1,1))

# %%
sns.countplot(agemod.reshape(-1),hue=train['Survived'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
train['Age']=agemod.reshape(-1)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  1.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  3.0      1
# 2                               Heikkinen, Miss. Laina    1  2.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  3.0      1
# 4                             Allen, Mr. William Henry    0  3.0      0
# ..                                                 ...  ...  ...    ...
# ...

# %%
train.drop(columns=['PassengerId','Name','Ticket','Fare','Cabin'],inplace=True)

# %%
train.to_csv('discrete_processed.csv',index=False)
